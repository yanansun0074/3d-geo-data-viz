# %%
import pydeck as pdk
import pandas as pd
# !pip install mercury
import mercury as mr
# Out:
# Collecting mercury
#   Downloading mercury-2.3.10.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 25.4 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting django==4.2.3 (from mercury)
#   Downloading Django-4.2.3-py3-none-any.whl.metadata (4.1 kB)
# Collecting djangorestframework==3.14.0 (from mercury)
#   Downloading djangorestframework-3.14.0-py3-none-any.whl.metadata (10 kB)
# Collecting django-filter==21.1 (from mercury)
#   Downloading django_filter-21.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown==3.3.6 (from mercury)
#   Downloading Markdown-3.3.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting celery>=5.1.2 (from mercury)
#   Downloading celery-5.3.6-py3-none-any.whl.metadata (21 kB)
# Collecting sqlalchemy==1.4.27 (from mercury)
#   Downloading SQLAlchemy-1.4.27-cp38-cp38-macosx_10_14_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: gevent in /opt/anaconda3/lib/python3.8/site-packages (from mercury) (21.1.2)
# Collecting nbconvert>=7.8.0 (from mercury)
#   Downloading nbconvert-7.16.3-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.8/site-packages (from mercury) (0.2.0)
# Collecting django-cors-headers==3.10.1 (from mercury)
#   Downloading django_cors_headers-3.10.1-py3-none-any.whl.metadata (15 kB)
# Collecting ipython>=7.30.1 (from mercury)
#   Downloading ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting ipykernel>=6.6.0 (from mercury)
#   Downloading ipykernel-6.29.4-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: psutil>=5.8.0 in /opt/anaconda3/lib/python3.8/site-packages (from mercury) (5.8.0)
# Collecting whitenoise>=5.3.0 (from mercury)
#   Downloading whitenoise-6.6.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.19.2 (from mercury)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting django-drf-filepond==0.4.1 (from mercury)
#   Downloading django_drf_filepond-0.4.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting croniter>=1.3.5 (from mercury)
#   Downloading croniter-2.0.3-py2.py3-none-any.whl.metadata (25 kB)
# Collecting pyppeteer==1.0.2 (from mercury)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting channels>=4.0.0 (from channels[daphne]>=4.0.0->mercury)
#   Downloading channels-4.0.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting websocket-client>=1.4.2 (from mercury)
#   Downloading websocket_client-1.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting execnb (from mercury)
#   Downloading execnb-0.1.5-py3-none-any.whl.metadata (3.3 kB)
# Collecting ipywidgets==8.0.3 (from mercury)
#   Downloading ipywidgets-8.0.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting dj-rest-auth==3.0.0 (from dj-rest-auth[with_social]==3.0.0->mercury)
#   Downloading dj-rest-auth-3.0.0.tar.gz (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting boto3==1.26.83 (from mercury)
#   Downloading boto3-1.26.83-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: cryptography in /opt/anaconda3/lib/python3.8/site-packages (from mercury) (3.4.7)
# Collecting pyopenssl>=23.1.1 (from mercury)
#   Downloading pyOpenSSL-24.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting bleach>=6.0.0 (from mercury)
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting itables>=2.0.0 (from mercury)
#   Downloading itables-2.0.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<1.30.0,>=1.29.83 (from boto3==1.26.83->mercury)
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.8/site-packages (from boto3==1.26.83->mercury) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from boto3==1.26.83->mercury) (0.6.0)
# WARNING: dj-rest-auth 3.0.0 does not provide the extra 'with-social'
# Collecting django-allauth<0.53.0,>=0.40.0 (from dj-rest-auth[with_social]==3.0.0->mercury)
#   Downloading django-allauth-0.52.0.tar.gz (728 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.3/728.3 kB 21.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting asgiref<4,>=3.6.0 (from django==4.2.3->mercury)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting sqlparse>=0.3.1 (from django==4.2.3->mercury)
#   Downloading sqlparse-0.4.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting backports.zoneinfo (from django==4.2.3->mercury)
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-macosx_10_14_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: requests>=2.20.1 in /opt/anaconda3/lib/python3.8/site-packages (from django-drf-filepond==0.4.1->mercury) (2.25.1)
# Requirement already satisfied: six>=1.14.0 in /opt/anaconda3/lib/python3.8/site-packages (from django-drf-filepond==0.4.1->mercury) (1.15.0)
# Collecting shortuuid>=0.5.0 (from django-drf-filepond==0.4.1->mercury)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting django-storages>=1.9.1 (from django-drf-filepond==0.4.1->mercury)
#   Downloading django_storages-1.14.2-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.8/site-packages (from djangorestframework==3.14.0->mercury) (2021.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.8/site-packages (from ipywidgets==8.0.3->mercury) (5.0.5)
# Collecting widgetsnbextension~=4.0 (from ipywidgets==8.0.3->mercury)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0 (from ipywidgets==8.0.3->mercury)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/lib/python3.8/site-packages (from markdown==3.3.6->mercury) (4.12.0)
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer==1.0.2->mercury)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting certifi>=2021 (from pyppeteer==1.0.2->mercury)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer==1.0.2->mercury)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyppeteer==1.0.2->mercury) (4.59.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /opt/anaconda3/lib/python3.8/site-packages (from pyppeteer==1.0.2->mercury) (1.26.4)
# Collecting websockets<11.0,>=10.0 (from pyppeteer==1.0.2->mercury)
#   Downloading websockets-10.4-cp38-cp38-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy==1.4.27->mercury) (1.0.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.8/site-packages (from bleach>=6.0.0->mercury) (0.5.1)
# Collecting billiard<5.0,>=4.2.0 (from celery>=5.1.2->mercury)
#   Downloading billiard-4.2.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting click-didyoumean>=0.3.0 (from celery>=5.1.2->mercury)
#   Downloading click_didyoumean-0.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting click-plugins>=1.1.1 (from celery>=5.1.2->mercury)
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting click-repl>=0.2.0 (from celery>=5.1.2->mercury)
#   Downloading click_repl-0.3.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting click<9.0,>=8.1.2 (from celery>=5.1.2->mercury)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting kombu<6.0,>=5.3.4 (from celery>=5.1.2->mercury)
#   Downloading kombu-5.3.6-py3-none-any.whl.metadata (3.1 kB)
# Collecting python-dateutil>=2.8.2 (from celery>=5.1.2->mercury)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting tzdata>=2022.7 (from celery>=5.1.2->mercury)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting vine<6.0,>=5.1.0 (from celery>=5.1.2->mercury)
#   Downloading vine-5.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting daphne>=4.0.0 (from channels[daphne]>=4.0.0->mercury)
#   Downloading daphne-4.1.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pytz (from djangorestframework==3.14.0->mercury)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting appnope (from ipykernel>=6.6.0->mercury)
#   Downloading appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# Collecting comm>=0.1.1 (from ipykernel>=6.6.0->mercury)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel>=6.6.0->mercury)
#   Downloading debugpy-1.8.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=6.6.0->mercury) (6.1.12)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel>=6.6.0->mercury)
#   Downloading jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel>=6.6.0->mercury)
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=6.6.0->mercury) (1.5.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=6.6.0->mercury) (20.9)
# Collecting pyzmq>=24 (from ipykernel>=6.6.0->mercury)
#   Downloading pyzmq-25.1.2-cp38-cp38-macosx_10_15_universal2.whl.metadata (4.9 kB)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=6.6.0->mercury) (6.1)
# Collecting traitlets>=4.3.1 (from ipywidgets==8.0.3->mercury)
#   Downloading traitlets-5.14.2-py3-none-any.whl.metadata (10 kB)
# Collecting backcall (from ipython>=7.30.1->mercury)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=7.30.1->mercury) (5.0.6)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=7.30.1->mercury) (0.17.2)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=7.30.1->mercury) (0.7.5)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 (from ipython>=7.30.1->mercury)
#   Downloading prompt_toolkit-3.0.43-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=7.30.1->mercury) (2.8.1)
# Collecting stack-data (from ipython>=7.30.1->mercury)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=7.30.1->mercury) (3.7.4.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.8/site-packages (from ipython>=7.30.1->mercury) (4.8.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from itables>=2.0.0->mercury) (1.22.4)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (from itables>=2.0.0->mercury) (1.2.4)
# Collecting beautifulsoup4 (from nbconvert>=7.8.0->mercury)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert>=7.8.0->mercury) (0.7.1)
# Collecting jinja2>=3.0 (from nbconvert>=7.8.0->mercury)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert>=7.8.0->mercury) (0.1.2)
# Collecting markupsafe>=2.0 (from nbconvert>=7.8.0->mercury)
#   Downloading MarkupSafe-2.1.5-cp38-cp38-macosx_10_9_x86_64.whl.metadata (3.0 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=7.8.0->mercury)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert>=7.8.0->mercury) (0.5.3)
# Collecting nbformat>=5.7 (from nbconvert>=7.8.0->mercury)
#   Downloading nbformat-5.10.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from nbconvert>=7.8.0->mercury) (1.4.3)
# Collecting tinycss2 (from nbconvert>=7.8.0->mercury)
#   Downloading tinycss2-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting cryptography (from mercury)
#   Downloading cryptography-42.0.5-cp37-abi3-macosx_10_12_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.8/site-packages (from cryptography->mercury) (1.14.5)
# Collecting fastcore>=1.5.5 (from execnb->mercury)
#   Downloading fastcore-1.5.29-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: zope.event in /opt/anaconda3/lib/python3.8/site-packages (from gevent->mercury) (4.5.0)
# Requirement already satisfied: zope.interface in /opt/anaconda3/lib/python3.8/site-packages (from gevent->mercury) (5.3.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from gevent->mercury) (52.0.0.post20210125)
# Collecting typing-extensions (from ipython>=7.30.1->mercury)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12->cryptography->mercury) (2.20)
# Collecting autobahn>=22.4.2 (from daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading autobahn-23.1.2.tar.gz (480 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.7/480.7 kB 15.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting twisted>=22.4 (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading twisted-24.3.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting python3-openid>=3.0.8 (from django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury)
#   Downloading python3_openid-3.2.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: requests-oauthlib>=0.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (1.3.1)
# Collecting pyjwt>=1.7 (from pyjwt[crypto]>=1.7->django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury)
#   Downloading PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.8/site-packages (from fastcore>=1.5.5->execnb->mercury) (23.3.2)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown==3.3.6->mercury) (3.4.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.30.1->mercury) (0.7.0)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.6.0->mercury)
#   Downloading platformdirs-4.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu<6.0,>=5.3.4->celery>=5.1.2->mercury)
#   Downloading amqp-5.2.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting async-generator (from nbclient>=0.5.0->nbconvert>=7.8.0->mercury)
#   Downloading async_generator-1.10-py3-none-any.whl.metadata (4.9 kB)
# Collecting fastjsonschema (from nbformat>=5.7->nbconvert>=7.8.0->mercury)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert>=7.8.0->mercury) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.30.1->mercury) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.30.1->mercury) (0.2.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mercury) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mercury) (2.10)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=7.8.0->mercury) (2.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging->ipykernel>=6.6.0->mercury) (2.4.7)
# Collecting executing>=1.2.0 (from stack-data->ipython>=7.30.1->mercury)
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=7.30.1->mercury)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=7.30.1->mercury)
#   Downloading pure_eval-0.2.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting txaio>=21.2.1 (from autobahn>=22.4.2->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading txaio-23.1.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting hyperlink>=21.0.0 (from autobahn>=22.4.2->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting attrs>=17.4.0 (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.8.0->mercury) (0.17.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.3.0->django-allauth<0.53.0,>=0.40.0->dj-rest-auth[with_social]==3.0.0->mercury) (3.2.0)
# Collecting automat>=0.8.0 (from twisted>=22.4->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading Automat-22.10.0-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting constantly>=15.1 (from twisted>=22.4->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting incremental>=22.10.0 (from twisted>=22.4->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading incremental-22.10.0-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting service-identity>=18.1.0 (from twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury)
#   Downloading service_identity-24.1.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pyasn1 in /opt/anaconda3/lib/python3.8/site-packages (from service-identity>=18.1.0->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /opt/anaconda3/lib/python3.8/site-packages (from service-identity>=18.1.0->twisted[tls]>=22.4->daphne>=4.0.0->channels[daphne]>=4.0.0->mercury) (0.2.8)
# Downloading boto3-1.26.83-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.7/134.7 kB 4.6 MB/s eta 0:00:00
# Downloading Django-4.2.3-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 36.4 MB/s eta 0:00:0000:0100:01
# Downloading django_cors_headers-3.10.1-py3-none-any.whl (12 kB)
# Downloading django_drf_filepond-0.4.1-py2.py3-none-any.whl (39 kB)
# Downloading django_filter-21.1-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 2.6 MB/s eta 0:00:00
# Downloading djangorestframework-3.14.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.8 MB/s eta 0:00:0000:01
# Downloading ipywidgets-8.0.3-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 4.2 MB/s eta 0:00:00
# Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 2.9 MB/s eta 0:00:00
# Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 2.6 MB/s eta 0:00:00
# Downloading SQLAlchemy-1.4.27-cp38-cp38-macosx_10_14_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.8 MB/s eta 0:00:0000:01
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 5.6 MB/s eta 0:00:00
# Downloading celery-5.3.6-py3-none-any.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.0/422.0 kB 13.6 MB/s eta 0:00:00
# Downloading channels-4.0.0-py3-none-any.whl (28 kB)
# Downloading croniter-2.0.3-py2.py3-none-any.whl (20 kB)
# Downloading ipykernel-6.29.4-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 kB 3.9 MB/s eta 0:00:00
# Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 17.9 MB/s eta 0:00:0000:01
# Downloading itables-2.0.0-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 6.5 MB/s eta 0:00:00
# Downloading nbconvert-7.16.3-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 7.6 MB/s eta 0:00:00
# Downloading pyOpenSSL-24.1.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 1.8 MB/s eta 0:00:00
# Downloading cryptography-42.0.5-cp37-abi3-macosx_10_12_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 40.3 MB/s eta 0:00:0000:0100:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 1.5 MB/s eta 0:00:00
# Downloading whitenoise-6.6.0-py3-none-any.whl (19 kB)
# Downloading execnb-0.1.5-py3-none-any.whl (13 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading backports.zoneinfo-0.2.1-cp38-cp38-macosx_10_14_x86_64.whl (35 kB)
# Downloading billiard-4.2.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 2.8 MB/s eta 0:00:00
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 49.4 MB/s eta 0:00:0000:0100:01
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading click_repl-0.3.0-py3-none-any.whl (10 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading daphne-4.1.0-py3-none-any.whl (30 kB)
# Downloading debugpy-1.8.1-py2.py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 48.7 MB/s eta 0:00:0000:0100:01
# Downloading django_storages-1.14.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 1.3 MB/s eta 0:00:00
# Downloading fastcore-1.5.29-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 2.1 MB/s eta 0:00:00
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 6.9 MB/s eta 0:00:00
# Downloading kombu-5.3.6-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 kB 7.3 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp38-cp38-macosx_10_9_x86_64.whl (14 kB)
# Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 1.4 MB/s eta 0:00:00
# Downloading nbformat-5.10.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.4 MB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.1/386.1 kB 11.3 MB/s eta 0:00:00
# Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 6.7 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading pyzmq-25.1.2-cp38-cp38-macosx_10_15_universal2.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 18.6 MB/s eta 0:00:0000:0100:01
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 1.3 MB/s eta 0:00:00
# Downloading traitlets-5.14.2-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 2.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading vine-5.1.0-py3-none-any.whl (9.6 kB)
# Downloading websockets-10.4-cp38-cp38-macosx_10_9_x86_64.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 3.3 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 37.2 MB/s eta 0:00:0000:01
# Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 5.1 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Downloading amqp-5.2.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 1.5 MB/s eta 0:00:00
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Downloading platformdirs-4.2.0-py3-none-any.whl (17 kB)
# Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Downloading python3_openid-3.2.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 4.4 MB/s eta 0:00:00
# Downloading twisted-24.3.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.4 MB/s eta 0:00:0000:0100:01
# Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 2.6 MB/s eta 0:00:00
# Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Downloading service_identity-24.1.0-py3-none-any.whl (12 kB)
# Downloading txaio-23.1.1-py2.py3-none-any.whl (30 kB)
# Building wheels for collected packages: mercury, dj-rest-auth, django-allauth, autobahn
#   Building wheel for mercury (pyproject.toml) ... done
#   Created wheel for mercury: filename=mercury-2.3.10-py3-none-any.whl size=2679203 sha256=dde69b1e58f4845c2046a706d814d3d4a4cf8f92460505eb3c837806dea397b3
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/22/f7/81/cf742853a8a4f5e5b418784c766f64907b8a042c1e567b4cf2
#   Building wheel for dj-rest-auth (setup.py) ... done
#   Created wheel for dj-rest-auth: filename=dj_rest_auth-3.0.0-py2.py3-none-any.whl size=155052 sha256=6d465271811aa1ebdf4f263dc121d2f8bd627fa6d0160f455669ec5ef2184f96
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/16/54/2c/e652e2491305f7e53bb1f3aeb8029d4f35386eb52b6ada4d48
#   Building wheel for django-allauth (setup.py) ... done
#   Created wheel for django-allauth: filename=django_allauth-0.52.0-py3-none-any.whl size=1063913 sha256=bb2a932af94506a89ca93b19d214f8f0c6a4ecc5ea0d4a77e7fdfa296999db44
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/ff/15/db/424d7d057f2f7a5144c629a39b33e5a74203a84418434e4a7c
#   Building wheel for autobahn (setup.py) ... done
#   Created wheel for autobahn: filename=autobahn-23.1.2-cp38-cp38-macosx_10_9_x86_64.whl size=674920 sha256=8c3d82a983314f5d91b3422c39c39156a71f28133d646e0aaa7301fc6d839bbc
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/f1/a4/a2/92e99f91e89b278683501744f82533a888326e65adffee831a
# Successfully built mercury dj-rest-auth django-allauth autobahn
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pytz, pyee, pure-eval, incremental, fastjsonschema, backcall, appdirs, widgetsnbextension, whitenoise, websockets, websocket-client, vine, tzdata, typing-extensions, txaio, traitlets, tinycss2, sqlparse, sqlalchemy, shortuuid, pyzmq, python3-openid, python-dotenv, python-dateutil, pyjwt, prompt-toolkit, platformdirs, mistune, markupsafe, jupyterlab-widgets, hyperlink, executing, debugpy, constantly, click, certifi, bleach, billiard, beautifulsoup4, backports.zoneinfo, attrs, async-generator, asttokens, appnope, stack-data, pyppeteer, matplotlib-inline, markdown, jupyter-core, jinja2, fastcore, cryptography, croniter, comm, click-repl, click-plugins, click-didyoumean, botocore, automat, asgiref, amqp, twisted, service-identity, pyopenssl, nbformat, kombu, ipython, django, autobahn, itables, ipykernel, execnb, djangorestframework, django-storages, django-filter, django-cors-headers, django-allauth, channels, celery, boto3, nbconvert, ipywidgets, django-drf-filepond, dj-rest-auth, daphne, mercury
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.1
#     Uninstalling pytz-2021.1:
#       Successfully uninstalled pytz-2021.1
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.1
#     Uninstalling widgetsnbextension-3.5.1:
#       Successfully uninstalled widgetsnbextension-3.5.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.7
#     Uninstalling SQLAlchemy-1.4.7:
#       Successfully uninstalled SQLAlchemy-1.4.7
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 20.0.0
#     Uninstalling pyzmq-20.0.0:
#       Successfully uninstalled pyzmq-20.0.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.17
#     Uninstalling prompt-toolkit-3.0.17:
#       Successfully uninstalled prompt-toolkit-3.0.17
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.3.7
#     Uninstalling Markdown-3.3.7:
#       Successfully uninstalled Markdown-3.3.7
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.7.1
#     Uninstalling jupyter-core-4.7.1:
#       Successfully uninstalled jupyter-core-4.7.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 3.4.7
#     Uninstalling cryptography-3.4.7:
#       Successfully uninstalled cryptography-3.4.7
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.27.20
#     Uninstalling botocore-1.27.20:
#       Successfully uninstalled botocore-1.27.20
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 20.0.1
#     Uninstalling pyOpenSSL-20.0.1:
#       Successfully uninstalled pyOpenSSL-20.0.1
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.1.3
#     Uninstalling nbformat-5.1.3:
#       Successfully uninstalled nbformat-5.1.3
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.22.0
#     Uninstalling ipython-7.22.0:
#       Successfully uninstalled ipython-7.22.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.3.4
#     Uninstalling ipykernel-5.3.4:
#       Successfully uninstalled ipykernel-5.3.4
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.24.20
#     Uninstalling boto3-1.24.20:
#       Successfully uninstalled boto3-1.24.20
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.3
#     Uninstalling ipywidgets-7.6.3:
#       Successfully uninstalled ipywidgets-7.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 4.0.1 requires alabaster<0.8,>=0.7, which is not installed.
# sphinx 4.0.1 requires babel>=1.3, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# conda-verify 3.4.2 requires backports.functools-lru-cache>=1.4, which is not installed.
# conda-verify 3.4.2 requires backports.tempfile, which is not installed.
# jupyter-server 1.4.1 requires anyio>=2.0.2, which is not installed.
# jupyterlab-server 2.4.0 requires babel, which is not installed.
# notebook 6.3.0 requires argon2-cffi, which is not installed.
# spacy 3.3.1 requires blis<0.8.0,>=0.4.0, which is not installed.
# spyder 4.2.5 requires applaunchservices>=0.1.7; platform_system == "Darwin", which is not installed.
# spyder 4.2.5 requires atomicwrites>=1.2.0, which is not installed.
# spyder 4.2.5 requires pyqt5<5.13, which is not installed.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# tensorboard 2.9.1 requires absl-py>=0.4, which is not installed.
# tensorflow 2.9.1 requires absl-py>=1.0.0, which is not installed.
# tensorflow 2.9.1 requires astunparse>=1.6.0, which is not installed.
# thinc 8.0.17 requires blis<0.8.0,>=0.4.0, which is not installed.
# sphinx 4.0.1 requires Jinja2<3.0,>=2.3, but you have jinja2 3.1.3 which is incompatible.
# sphinx 4.0.1 requires MarkupSafe<2.0, but you have markupsafe 2.1.5 which is incompatible.
# Successfully installed amqp-5.2.0 appdirs-1.4.4 appnope-0.1.4 asgiref-3.8.1 asttokens-2.4.1 async-generator-1.10 attrs-23.2.0 autobahn-23.1.2 automat-22.10.0 backcall-0.2.0 backports.zoneinfo-0.2.1 beautifulsoup4-4.12.3 billiard-4.2.0 bleach-6.1.0 boto3-1.26.83 botocore-1.29.165 celery-5.3.6 certifi-2024.2.2 channels-4.0.0 click-8.1.7 click-didyoumean-0.3.1 click-plugins-1.1.1 click-repl-0.3.0 comm-0.2.2 constantly-23.10.4 croniter-2.0.3 cryptography-42.0.5 daphne-4.1.0 debugpy-1.8.1 dj-rest-auth-3.0.0 django-4.2.3 django-allauth-0.52.0 django-cors-headers-3.10.1 django-drf-filepond-0.4.1 django-filter-21.1 django-storages-1.14.2 djangorestframework-3.14.0 execnb-0.1.5 executing-2.0.1 fastcore-1.5.29 fastjsonschema-2.19.1 hyperlink-21.0.0 incremental-22.10.0 ipykernel-6.29.4 ipython-8.12.3 ipywidgets-8.0.3 itables-2.0.0 jinja2-3.1.3 jupyter-core-5.7.2 jupyterlab-widgets-3.0.10 kombu-5.3.6 markdown-3.3.6 markupsafe-2.1.5 matplotlib-inline-0.1.6 mercury-2.3.10 mistune-3.0.2 nbconvert-7.16.3 nbformat-5.10.3 platformdirs-4.2.0 prompt-toolkit-3.0.43 pure-eval-0.2.2 pyee-8.2.2 pyjwt-2.8.0 pyopenssl-24.1.0 pyppeteer-1.0.2 python-dateutil-2.9.0.post0 python-dotenv-1.0.1 python3-openid-3.2.0 pytz-2024.1 pyzmq-25.1.2 service-identity-24.1.0 shortuuid-1.0.13 sqlalchemy-1.4.27 sqlparse-0.4.4 stack-data-0.6.3 tinycss2-1.2.1 traitlets-5.14.2 twisted-24.3.0 txaio-23.1.1 typing-extensions-4.10.0 tzdata-2024.1 vine-5.1.0 websocket-client-1.7.0 websockets-10.4 whitenoise-6.6.0 widgetsnbextension-4.0.10
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/0q/7vty58gd1wd5gtv92sj6pq0w0000gn/T/ipykernel_7412/3778289898.py in <module>
#       2 import pandas as pd
#       3 get_ipython().system('pip install mercury')
# ----> 4 import mercury as mr
#
# ModuleNotFoundError: No module named 'mercury'

# %%
demo = mr.Select(label="Select demo", choices=["ArcLayer", "GeoJsonLayer", "HexagonLayer"])

# %%
if demo.value == "ArcLayer":

    DATA_URL = "https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/geojson/vancouver-blocks.json"
    LAND_COVER = [[[-123.0, 49.196], [-123.0, 49.324], [-123.306, 49.324], [-123.306, 49.196]]]

    INITIAL_VIEW_STATE = pdk.ViewState(latitude=49.254, longitude=-123.13, zoom=11, max_zoom=16, pitch=45, bearing=0)

    polygon = pdk.Layer(
        "PolygonLayer",
        LAND_COVER,
        stroked=False,
        # processes the data as a flat longitude-latitude pair
        get_polygon="-",
        get_fill_color=[0, 0, 0, 20],
    )

    geojson = pdk.Layer(
        "GeoJsonLayer",
        DATA_URL,
        opacity=0.8,
        stroked=False,
        filled=True,
        extruded=True,
        wireframe=True,
        get_elevation="properties.valuePerSqm / 20",
        get_fill_color="[255, 255, properties.growth * 255]",
        get_line_color=[255, 255, 255],
    )

    r = pdk.Deck(layers=[polygon, geojson], initial_view_state=INITIAL_VIEW_STATE)

# %%
if demo.value == "GeoJsonLayer":
    DATA_URL = "https://raw.githubusercontent.com/ajduberstein/sf_public_data/master/bay_area_commute_routes.csv"
    # A bounding box for downtown San Francisco, to help filter this commuter data
    DOWNTOWN_BOUNDING_BOX = [
        -122.43135291617365,
        37.766492914983864,
        -122.38706428091974,
        37.80583561830737,
    ]


    def in_bounding_box(point):
        """Determine whether a point is in our downtown bounding box"""
        lng, lat = point
        in_lng_bounds = DOWNTOWN_BOUNDING_BOX[0] <= lng <= DOWNTOWN_BOUNDING_BOX[2]
        in_lat_bounds = DOWNTOWN_BOUNDING_BOX[1] <= lat <= DOWNTOWN_BOUNDING_BOX[3]
        return in_lng_bounds and in_lat_bounds


    df = pd.read_csv(DATA_URL)
    # Filter to bounding box
    df = df[df[["lng_w", "lat_w"]].apply(lambda row: in_bounding_box(row), axis=1)]

    GREEN_RGB = [0, 255, 0, 40]
    RED_RGB = [240, 100, 0, 40]

    # Specify a deck.gl ArcLayer
    arc_layer = pdk.Layer(
        "ArcLayer",
        data=df,
        get_width="S000 * 2",
        get_source_position=["lng_h", "lat_h"],
        get_target_position=["lng_w", "lat_w"],
        get_tilt=15,
        get_source_color=RED_RGB,
        get_target_color=GREEN_RGB,
        pickable=True,
        auto_highlight=True,
    )

    view_state = pdk.ViewState(
        latitude=37.7576171,
        longitude=-122.5776844,
        bearing=45,
        pitch=50,
        zoom=8,
    )


    TOOLTIP_TEXT = {"html": "{S000} jobs <br /> Home of commuter in red; work location in green"}
    r = pdk.Deck(arc_layer, initial_view_state=view_state, tooltip=TOOLTIP_TEXT)

# %%
if demo.value == "HexagonLayer":
    HEXAGON_LAYER_DATA = (
        "https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/3d-heatmap/heatmap-data.csv"  # noqa
    )

    # Define a layer to display on a map
    layer = pdk.Layer(
        "HexagonLayer",
        HEXAGON_LAYER_DATA,
        get_position=["lng", "lat"],
        auto_highlight=True,
        elevation_scale=50,
        pickable=True,
        elevation_range=[0, 3000],
        extruded=True,
        coverage=1,
    )

    # Set the viewport location
    view_state = pdk.ViewState(
        longitude=-1.415,
        latitude=52.2323,
        zoom=6,
        min_zoom=5,
        max_zoom=15,
        pitch=40.5,
        bearing=-27.36,
    )

    # Render
    r = pdk.Deck(layers=[layer], initial_view_state=view_state)

# %%
r
# Out:
# {
#   "initialViewState": {
#     "bearing": 0,
#     "latitude": 49.254,
#     "longitude": -123.13,
#     "maxZoom": 16,
#     "pitch": 45,
#     "zoom": 11
#   },
#   "layers": [
#     {
#       "@@type": "PolygonLayer",
#       "data": [
#         [
#           [
#             -123.0,
#             49.196
#           ],
#           [
#             -123.0,
#             49.324
#           ],
#           [
#             -123.306,
#             49.324
#           ],
#           [
#             -123.306,
#             49.196
#           ]
#         ]
#       ],
#       "getFillColor": [
#         0,
#         0,
#         0,
#         20
#       ],
#       "getPolygon": "@@=-",
#       "id": "c1b34400-6a2f-471d-b504-02a109943f55",
#       "stroked": false
#     },
#     {
#       "@@type": "GeoJsonLayer",
#       "data": "https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/geojson/vancouver-blocks.json",
#       "extruded": true,
#       "filled": true,
#       "getElevation": "@@=properties.valuePerSqm / 20",
#       "getFillColor": "@@=[255, 255, properties.growth * 255]",
#       "getLineColor": [
#         255,
#         255,
#         255
#       ],
#       "id": "e3ebebba-2806-4bf8-937a-e2ca8b4eeeb9",
#       "opacity": 0.8,
#       "stroked": false,
#       "wireframe": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }
